# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import skimage.io as io

import torch

# %%
img1=cv2.imread('4.png')

# %%
print(np.shape(img1))
# Out:
# (112, 112, 3)

# %% [markdown]
# # face recognition using Hough Transform, may not be accurate

# %%
plt.imshow(img1)

# %%
img=np.array(img1)
if img.ndim == 3: img = img.mean(axis=-1)
img = img / img.max()
#chopped = pr.chop_image(img, size, overlap=overlap)

# %%
img = (img*255).astype(np.uint8)
        #new=np.array(result[i][1])
circles=cv.HoughCircles(img,cv.HOUGH_GRADIENT,1,20,param1=40,param2=25,minRadius=40,maxRadius=60)

# %%
print(circles)
# Out:
# [[[54.5 53.5 51.6]]]

# %%
plt.imshow(img1)
plt.scatter(np.array(circles[0])[0:,0],np.array(circles[0])[:,1],marker='+',color='red')

# %% [markdown]
# # face recognition using CV2 already trained Model, much better

# %%
import cv2

# Load the cascade
#face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
#face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
#eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')


# Read the input image
img = cv2.imread('Angelina.png')
# Convert into grayscale


#img=np.array(img)
#if img.ndim == 3: img = img.mean(axis=-1)
#img = img / img.max()


gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.1,2)
#faces = face_cascade.detectMultiScale(img, 1.1,4)
# Draw rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
# Display the output

# %%
import cv2


face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')


img = cv2.imread('Angelina.png')


gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


faces = face_cascade.detectMultiScale(gray, 1.1,1) 


for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

# %%
plt.imshow(img) 
plt.scatter(50,47,color='pink')
plt.scatter(50,0,color='pink')
plt.scatter(47,47+195,color='pink')

plt.scatter(50+195, 47,color='pink')
plt.scatter(50+195,47+195,color='pink')

# %% [markdown]
# # segmentation and resizing image

# %%
print(np.shape(img))
# Out:
# (300, 400, 3)

# %%
cropped_image = img[faces[0][1]:faces[0][1]+faces[0][3], faces[0][0]:faces[0][0]+faces[0][2]] # Slicing to crop the image

# %%
plt.imshow(cropped_image)

# %%
resizeimg=cv.resize(cropped_image,(112,112))

# %%
plt.imshow(resizeimg)

# %%
img2=cv2.imread('40.png')

# %%
plt.imshow(img2)

# %%
resizeimg2=cv.resize(img2,(256,256))
plt.imshow(resizeimg2)

# %%
print(np.shape(split))
# Out:
# (195, 400, 3)

# %%
print(faces) #50, 47 is the begining of the rectangle, and then
# Out:
# [[ 50  47 195 195]]

# %%
print(np.shape(faces))
print(faces)
# Out:
# (1, 4)
# [[ 50  47 195 195]]

# %%
#channel to

# %%
frames=[]
for i in range(0,72):
    img=cv.imread(str(i)+'.png')
    frames.append(img)

# %%
from matplotlib import pyplot as plt
  
# create figure
fig = plt.figure(figsize=(10, 8))
  
# setting values to rows and column variables
rows = 7
columns = 10
  
# reading images
for i in range(0,73):
    fig.add_subplot(rows,columns,i+1)
    plt.imshow(frames[i])
    plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [37], line 12
#      10 # reading images
#      11 for i in range(0,73):
# ---> 12     fig.add_subplot(rows,columns,i+1)
#      13     plt.imshow(frames[i])
#      14     plt.axis('off')
#
# File ~/miniforge3/lib/python3.9/site-packages/matplotlib/figure.py:772, in FigureBase.add_subplot(self, *args, **kwargs)
#     769         args = tuple(map(int, str(args[0])))
#     770     projection_class, pkw = self._process_projection_requirements(
#     771         *args, **kwargs)
# --> 772     ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     773     key = (projection_class, pkw)
#     774 return self._add_axes_internal(ax, key)
#
# File ~/miniforge3/lib/python3.9/site-packages/matplotlib/axes/_subplots.py:36, in SubplotBase.__init__(self, fig, *args, **kwargs)
# ...

# %%
spliteg=np.vsplit(img1,2)
segments=[]
for i in range(len(spliteg)):
    vertical=np.hsplit(spliteg[i],2)
    segments.append(vertical)

# %%
plt.imshow(spliteg[0][0])

# %%
print(max(img1[0][:,0]))
# Out:
# 55
